# %%
import sqlalchemy as db
import numpy as np
import os
import json
import pandas as pd
# Out:
# '0.24.2'

# %%
with open('config.json', 'r') as f:
    config = json.load(f)

with open(os.path.expanduser("~/.pgpass"), 'r') as f:
    secrets = None
    for line in f:
        if config['host'] in line:
            secrets = line.strip().split(':')
            break
    
if secrets is None:
    raise ValueError('did not find '+config.wimbledon_config['host']+' in ~/.pgpass')

# %%
url = db.engine.url.URL(drivername=config['drivername'], 
                        username=secrets[-2], 
                        password=secrets[-1],
                        host=config['host'], 
                        database=config['database'])

engine = db.create_engine(url)

connection = engine.connect()
metadata = db.MetaData(schema='forecast')

# %%
def csv_to_sql(schema, table_name, usecols, parse_dates, ints_with_nan, index_col='id'):
    
    csv = pd.read_csv('../data/'+schema+'/'+table_name+'.csv',
                      usecols=usecols,
                      index_col=index_col,
                      parse_dates=parse_dates,
                      infer_datetime_format=True)
    
    for col in ints_with_nan:
        # Integer columns with NaN: Requires pandas 0.24 (otherwise ids end up as floats)
        csv[col] = csv[col].astype('Int64')
        
    if 'roles' in usecols:
        csv['roles'] = csv['roles'].str.replace(r"[\[\]\']", "", regex=True)
        csv.rename(columns={'roles':'role'},inplace=True)
        
        roles = pd.read_csv('../data/'+schema+'/roles.csv')
        csv['role'] = pd.merge(csv['role'], 
                               roles[['name','id']], 
                               how='left', left_on='role', right_on='name')['id']
        
        csv['role'] = csv['role'].astype('Int64')
        
    csv.columns = csv.columns.str.replace('.','_')
    
    metadata = db.MetaData(schema=schema)
   
    csv.to_sql(table_name, connection, schema=schema, if_exists='append')
    table = db.Table(table_name, metadata, autoload=True, autoload_with=engine)
    results = connection.execute(db.select([table])).fetchall()
    df = pd.DataFrame(results)
    df.columns = results[0].keys()
    
    print(repr(metadata.tables[schema+'.'+table_name]))
    display(df.head())

# %% [markdown]
# ## Harvest

# %%
csv_to_sql('harvest', 'clients', 
           usecols=['id', 'name', 'is_active'],
           parse_dates=False,
           ints_with_nan=[],
           index_col='id')
# Out:
# Table('clients', MetaData(bind=None), Column('id', INTEGER(), table=<clients>, primary_key=True, nullable=False), Column('name', TEXT(), table=<clients>), Column('is_active', BOOLEAN(), table=<clients>), schema='harvest')
#         id                   name  is_active
# 0  7889179         Wellcome Trust       True
# 1  7738296                    TIL       True
# 2  7738175                  Leeds       True
# 3  7515887  Alan Turing Institute       True
# 4  7444895                    SPF       True

# %%
csv_to_sql('harvest', 'projects', 
           usecols=['id', 'name', 'budget', 'code', 'starts_on', 'ends_on', 'client.id', 'notes', 'is_active'],
           parse_dates=['starts_on', 'ends_on'],
           ints_with_nan=['client.id'],
           index_col='id')
# Out:
# Table('projects', MetaData(bind=None), Column('id', INTEGER(), table=<projects>, primary_key=True, nullable=False), Column('name', TEXT(), table=<projects>), Column('budget', DOUBLE_PRECISION(precision=53), table=<projects>), Column('code', TEXT(), table=<projects>), Column('starts_on', DATE(), table=<projects>), Column('ends_on', DATE(), table=<projects>), Column('client_id', INTEGER(), ForeignKey('harvest.clients.id'), table=<projects>), Column('notes', TEXT(), table=<projects>), Column('is_active', BOOLEAN(), table=<projects>), schema='harvest')
#          id                                 name  budget  code   starts_on  \
# 0  20843757                    Urban Agriculture     NaN  None        None
# 1  20684616                    Wimbledon Planner     NaN  None        None
# 2  20508323                  Mini-bridge support     NaN  None        None
# 3  20463792  Uncertainty in Government Modelling     NaN  None  2019-04-01
# 4  20431477             Urban systems resilience     NaN  None  2019-10-01
#
#       ends_on  client_id                                              notes  \
# 0        None    7394384                                               None
# 1        None    7236211  Producing time-tracking and project forecastin...
# 2        None    7394384                                               None
# 3  2020-03-31    7394384                                               None
# 4  2019-12-31    7515887                                               None
#
#    is_active
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True

# %%
csv_to_sql('harvest', 'roles', 
           usecols=['id', 'name'],
           parse_dates=False,
           ints_with_nan=[],
           index_col='id')
# Out:
# Table('roles', MetaData(bind=None), Column('id', INTEGER(), table=<roles>, primary_key=True, nullable=False), Column('name', TEXT(), table=<roles>), schema='harvest')
#        id                        name
# 0  510325           Community Manager
# 1  495088                     example
# 2  493302    Research Project Manager
# 3  493301             Project Manager
# 4  463110  Research Software Engineer

# %%
csv_to_sql('harvest', 'users', 
           usecols=['id', 'first_name', 'last_name', 'email', 'roles', 'weekly_capacity', 'is_active', 'is_project_manager', 'is_contractor'],
           parse_dates=False,
           ints_with_nan=[],
           index_col='id')
# Out:
# Table('users', MetaData(bind=None), Column('id', INTEGER(), table=<users>, primary_key=True, nullable=False), Column('first_name', TEXT(), table=<users>), Column('last_name', TEXT(), table=<users>), Column('email', TEXT(), table=<users>), Column('role', INTEGER(), ForeignKey('harvest.roles.id'), table=<users>), Column('weekly_capacity', INTEGER(), table=<users>), Column('is_active', BOOLEAN(), table=<users>), Column('is_project_manager', BOOLEAN(), table=<users>), Column('is_contractor', BOOLEAN(), table=<users>), schema='harvest')
#         id first_name last_name                  email  role  weekly_capacity  \
# 0  2764181    Gabriel   Hanganu  ghanganu@turing.ac.uk  None                0
# 1  2747278     Oliver   Forrest  oforrest@turing.ac.uk  None           144000
# 2  2603234       Jack   Roberts  jroberts@turing.ac.uk  None           144000
# 3  2593895     Amaani   Hoddoon  ahoddoon@turing.ac.uk  None           144000
# 4  2593869      Oscar     Giles    ogiles@turing.ac.uk  None           144000
#
#    is_active  is_project_manager  is_contractor
# 0       True               False          False
# 1       True               False          False
# 2       True               False          False
# 3       True               False          False
# 4       True               False          False

# %%
csv_to_sql('harvest', 'tasks', 
           usecols=['id', 'name', 'is_active'],
           parse_dates=False,
           ints_with_nan=[],
           index_col='id')
# Out:
# Table('tasks', MetaData(bind=None), Column('id', INTEGER(), table=<tasks>, primary_key=True, nullable=False), Column('name', TEXT(), table=<tasks>), Column('is_active', BOOLEAN(), table=<tasks>), schema='harvest')
#          id                     name  is_active
# 0  12128239                HoloGraph       True
# 1  12050549  Wrattler racket backend       True
# 2  11872228                Reviewing       True
# 3  11872227           RepRes lunches       True
# 4  11872226           Content review       True

# %%
csv_to_sql('harvest', 'time_entries', 
           usecols=['id', 'user.id', 'project.id', 'task.id', 'spent_date', 'hours', 'notes'],
           parse_dates=['spent_date'],
           ints_with_nan=['user.id','project.id','task.id'],
           index_col='id')
# Out:
# Table('time_entries', MetaData(bind=None), Column('id', INTEGER(), table=<time_entries>, primary_key=True, nullable=False), Column('user_id', INTEGER(), ForeignKey('harvest.users.id'), table=<time_entries>), Column('project_id', INTEGER(), ForeignKey('harvest.projects.id'), table=<time_entries>), Column('task_id', INTEGER(), ForeignKey('harvest.tasks.id'), table=<time_entries>), Column('spent_date', DATE(), table=<time_entries>), Column('hours', DOUBLE_PRECISION(precision=53), table=<time_entries>), Column('notes', TEXT(), table=<time_entries>), schema='harvest')
#           id  user_id  project_id   task_id  spent_date  hours notes
# 0  994616111  2360118    18946187  10375716  2019-04-28    2.0  None
# 1  994616109  2360118    18946187  10375716  2019-04-27    2.0  None
# 2  994677858  2360132    18753173  10665526  2019-04-26    4.0  None
# 3  994677798  2360132    18793805  10375716  2019-04-26    2.0  None
# 4  994677797  2360132    18946187  10375716  2019-04-26    2.0  None

# %%
csv_to_sql('harvest', 'user_assignments', 
           usecols=['id', 'user.id', 'project.id', 'is_active', 'is_project_manager'],
           parse_dates=False,
           ints_with_nan=['user.id','project.id'],
           index_col='id')
# Out:
# Table('user_assignments', MetaData(bind=None), Column('id', INTEGER(), table=<user_assignments>, primary_key=True, nullable=False), Column('user_id', INTEGER(), ForeignKey('harvest.users.id'), table=<user_assignments>), Column('project_id', INTEGER(), ForeignKey('harvest.projects.id'), table=<user_assignments>), Column('is_active', BOOLEAN(), table=<user_assignments>), Column('is_project_manager', BOOLEAN(), table=<user_assignments>), schema='harvest')
#           id  user_id  project_id  is_active  is_project_manager
# 0  197387056  2443850    18946199       True               False
# 1  196822066  2603234    18753173       True               False
# 2  196269279  2463055    19471496       True               False
# 3  196227290  2392818    20843757       True                True
# 4  196213146  2593869    19930508       True               False

# %%
csv_to_sql('harvest', 'task_assignments', 
           usecols=['id', 'task.id', 'project.id'],
           parse_dates=False,
           ints_with_nan=['task.id','project.id'],
           index_col='id')
# Out:
# Table('task_assignments', MetaData(bind=None), Column('id', INTEGER(), table=<task_assignments>, primary_key=True, nullable=False), Column('project_id', INTEGER(), ForeignKey('harvest.projects.id'), table=<task_assignments>), Column('task_id', INTEGER(), ForeignKey('harvest.tasks.id'), table=<task_assignments>), schema='harvest')
#           id  project_id   task_id
# 0  225689177    18650735  12128239
# 1  224600345    20843757  10638208
# 2  224600344    20843757  10911795
# 3  224600343    20843757  11872225
# 4  224600342    20843757  10375718

# %% [markdown]
# ## Forecast

# %%
csv_to_sql('forecast', 'clients', 
           usecols=['id', 'name', 'harvest_id', 'archived'],
           parse_dates=False,
           ints_with_nan=['harvest_id'],
           index_col='id')
# Out:
# Table('clients', MetaData(bind=None), Column('id', INTEGER(), table=<clients>, primary_key=True, nullable=False), Column('name', TEXT(), table=<clients>), Column('harvest_id', INTEGER(), ForeignKey('harvest.clients.id'), table=<clients>), Column('archived', BOOLEAN(), table=<clients>), schema='forecast')
#        id                                  name  harvest_id  archived
# 0  732424             The Alan Turing Institute         NaN     False
# 1  732425                                 Intel         NaN     False
# 2  744985                              Wrattler         NaN     False
# 3  745536  Wilfrid Kendall (Warwick University)         NaN     False
# 4  745537                                  HSBC         NaN     False

# %%
csv_to_sql('forecast', 'projects', 
           usecols=['id', 'name', 'code', 'start_date', 'end_date', 'client_id', 'harvest_id', 'notes', 'archived'],
           parse_dates=['start_date', 'end_date'],
           ints_with_nan=['client_id','harvest_id'],
           index_col='id')
# Out:
# Table('projects', MetaData(bind=None), Column('id', INTEGER(), table=<projects>, primary_key=True, nullable=False), Column('name', TEXT(), table=<projects>), Column('code', TEXT(), table=<projects>), Column('start_date', DATE(), table=<projects>), Column('end_date', DATE(), table=<projects>), Column('client_id', INTEGER(), ForeignKey('forecast.clients.id'), table=<projects>), Column('harvest_id', INTEGER(), ForeignKey('harvest.projects.id'), table=<projects>), Column('notes', TEXT(), table=<projects>), Column('archived', BOOLEAN(), table=<projects>), schema='forecast')
#         id                     name       code  start_date    end_date  \
# 0  1684536                 Time Off       None        None        None
# 1  1684539  Sargasso (Intel Sparse)  R-INT-001  2018-04-01  2018-12-31
# 2  1723251                     AIDA       None  2018-04-01  2019-03-31
# 3  1723252          DetectorChecker       None  2018-08-20  2019-01-31
# 4  1723253                 HSBC EDS  R-HSB-001  2018-04-01  2018-10-31
#
#    client_id  harvest_id notes  archived
# 0        NaN         NaN  None     False
# 1   769477.0  18266019.0  None     False
# 2   761645.0  18644291.0  None     False
# 3   761647.0  18644652.0  None     False
# 4   769469.0  18644656.0  None     False

# %%
csv_to_sql('forecast', 'roles', 
           usecols=['id', 'name', 'harvest_role_id'],
           parse_dates=False,
           ints_with_nan=['harvest_role_id'],
           index_col='id')
# Out:
# Table('roles', MetaData(bind=None), Column('id', INTEGER(), table=<roles>, primary_key=True, nullable=False), Column('name', TEXT(), table=<roles>), Column('harvest_role_id', INTEGER(), ForeignKey('harvest.roles.id'), table=<roles>), schema='forecast')
#        id                               name  harvest_role_id
# 0  170095            Research Data Scientist           450792
# 1  170096  Senior Research Software Engineer           450793
# 2  170097     Senior Research Data Scientist           450794
# 3  170099  Principal Research Data Scientist           450796
# 4  170100   Director of Research Engineering           450797

# %%
csv_to_sql('forecast', 'people', 
           usecols=['id', 'first_name', 'last_name', 'email', 'roles', 'harvest_user_id', 'login', 'subscribed', 'admin',
                   'archived', 'weekly_capacity', 'working_days.monday', 'working_days.tuesday', 'working_days.wednesday',
                   'working_days.thursday', 'working_days.friday', 'working_days.saturday', 'working_days.sunday'],
           parse_dates=False,
           ints_with_nan=['harvest_user_id'],
           index_col='id')
# Out:
# Table('people', MetaData(bind=None), Column('id', INTEGER(), table=<people>, primary_key=True, nullable=False), Column('first_name', TEXT(), table=<people>), Column('last_name', TEXT(), table=<people>), Column('email', TEXT(), table=<people>), Column('role', INTEGER(), table=<people>), Column('harvest_user_id', INTEGER(), ForeignKey('harvest.users.id'), table=<people>), Column('login', TEXT(), table=<people>), Column('subscribed', BOOLEAN(), table=<people>), Column('admin', BOOLEAN(), table=<people>), Column('archived', BOOLEAN(), table=<people>), Column('weekly_capacity', INTEGER(), table=<people>), Column('working_days_monday', BOOLEAN(), table=<people>), Column('working_days_tuesday', BOOLEAN(), table=<people>), Column('working_days_wednesday', BOOLEAN(), table=<people>), Column('working_days_thursday', BOOLEAN(), table=<people>), Column('working_days_friday', BOOLEAN(), table=<people>), Column('working_days_saturday', BOOLEAN(), table=<people>), Column('working_days_sunday', BOOLEAN(), table=<people>), schema='forecast')
#        id first_name  last_name                    email  role  \
# 0  399979     Oliver  Strickson  ostrickson@turing.ac.uk  None
# 1  408178      Angus   Williams   awilliams@turing.ac.uk  None
# 2  408179      David     Beavan     dbeavan@turing.ac.uk  None
# 3  408180    Evelina   Gabasova   egabasova@turing.ac.uk  None
# 4  408181   Giovanni  Colavizza  gcolavizza@turing.ac.uk  None
#
#    harvest_user_id     login  subscribed  admin  archived  weekly_capacity  \
# 0        2315537.0   enabled        True   True     False              NaN
# 1              NaN  disabled       False  False     False              NaN
# 2        2360118.0   enabled       False   True     False              NaN
# 3        2360119.0   enabled       False   True     False              NaN
# 4        2360121.0   enabled       False   True     False              NaN
#
#    working_days_monday  working_days_tuesday  working_days_wednesday  \
# 0                 True                  True                    True
# 1                 True                  True                    True
# 2                 True                  True                    True
# 3                 True                  True                    True
# 4                 True                  True                    True
#
#    working_days_thursday  working_days_friday  working_days_saturday  \
# 0                   True                 True                  False
# 1                   True                 True                  False
# 2                   True                 True                  False
# 3                   True                 True                  False
# 4                   True                 True                  False
#
#    working_days_sunday
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False

# %%
csv_to_sql('forecast', 'placeholders', 
           usecols=['id', 'name', 'roles', 'archived'],
           parse_dates=False,
           ints_with_nan=[],
           index_col='id')
# Out:
# Table('placeholders', MetaData(bind=None), Column('id', INTEGER(), table=<placeholders>, primary_key=True, nullable=False), Column('name', TEXT(), table=<placeholders>), Column('role', INTEGER(), table=<placeholders>), Column('archived', BOOLEAN(), table=<placeholders>), schema='forecast')
#       id                 name  role  archived
# 0  23092  Resource Required 1  None     False
# 1  23093         Newcastle 01  None     False
# 2  23094         Edinburgh 01  None     False
# 3  24360        Birmingham 01  None     False
# 4  24361            SPF RA 01  None     False

# %%
csv_to_sql('forecast', 'milestones', 
           usecols=['id', 'date', 'project_id'],
           parse_dates=['date'],
           ints_with_nan=['project_id'],
           index_col='id')
# Out:
# Table('milestones', MetaData(bind=None), Column('id', INTEGER(), table=<milestones>, primary_key=True, nullable=False), Column('date', DATE(), table=<milestones>), Column('project_id', INTEGER(), ForeignKey('forecast.projects.id'), table=<milestones>), schema='forecast')
#         id        date  project_id
# 0  1727379  2018-08-30     1684539
# 1  1906966  2019-01-02     1823898
# 2  2088931  2019-03-19     1969208

# %%
csv_to_sql('forecast', 'assignments', 
           usecols=['id', 'person_id', 'placeholder_id', 'project_id', 'start_date','end_date','allocation','notes'],
           parse_dates=['start_date','end_date'],
           ints_with_nan=['person_id','placeholder_id','project_id'],
           index_col='id')
# Out:
# Table('assignments', MetaData(bind=None), Column('id', INTEGER(), table=<assignments>, primary_key=True, nullable=False), Column('person_id', INTEGER(), ForeignKey('forecast.people.id'), table=<assignments>), Column('placeholder_id', INTEGER(), ForeignKey('forecast.placeholders.id'), table=<assignments>), Column('project_id', INTEGER(), ForeignKey('forecast.projects.id'), table=<assignments>), Column('start_date', DATE(), table=<assignments>), Column('end_date', DATE(), table=<assignments>), Column('allocation', INTEGER(), table=<assignments>), Column('notes', TEXT(), table=<assignments>), schema='forecast')
#          id  person_id  placeholder_id  project_id  start_date    end_date  \
# 0  19314451   408190.0             NaN     1723252  2018-11-01  2018-11-30
# 1  19314475   408190.0             NaN     1723263  2018-11-01  2018-12-31
# 2  19314509   408187.0             NaN     1723263  2018-11-01  2018-12-31
# 3  19314518   408187.0             NaN     1723251  2018-11-01  2019-03-31
# 4  19314525   408186.0             NaN     1723251  2018-11-01  2019-03-31
#
#    allocation notes
# 0       14400  None
# 1       14400  None
# 2       14400  None
# 3       14400  None
# 4       14400  None

# %% [markdown]
# ## Read

# %%
table_name = 'people'
table = db.Table(table_name, metadata, autoload=True, autoload_with=engine)
results = connection.execute(db.select([table])).fetchall()
df = pd.DataFrame(results)
df.columns = results[0].keys()
df
# Out:
#         id first_name     last_name                       email  role  \
# 0   399979     Oliver     Strickson     ostrickson@turing.ac.uk  None
# 1   408178      Angus      Williams      awilliams@turing.ac.uk  None
# 2   408179      David        Beavan        dbeavan@turing.ac.uk  None
# 3   408180    Evelina      Gabasova      egabasova@turing.ac.uk  None
# 4   408181   Giovanni     Colavizza     gcolavizza@turing.ac.uk  None
# 5   408182      James        Geddes        jgeddes@turing.ac.uk  None
# 6   408183      James  Hetherington  jhetherington@turing.ac.uk  None
# 7   408184     Louise        Bowler        lbowler@turing.ac.uk  None
# 8   408185     Martin      O'Reilly       moreilly@turing.ac.uk  None
# 9   408186        May          Yong          myong@turing.ac.uk  None
# 10  408187       Nick        Barlow        nbarlow@turing.ac.uk  None
# 11  408188      Radka     Jersakova     rjersakova@turing.ac.uk  None
# 12  408189    Timothy        Hobson        thobson@turing.ac.uk  None
# 13  408190      Tomas     Lazauskas     tlazauskas@turing.ac.uk  None
# 14  417332     Camila  Rangel Smith   crangelsmith@turing.ac.uk  None
# 15  428845      Sarah        Gibson        sgibson@turing.ac.uk  None
# 16  428846      James      Robinson      jrobinson@turing.ac.uk  None
# 17  428847     Miguel         Morin         mmorin@turing.ac.uk  None
# 18  432681       Eric          Daub          edaub@turing.ac.uk  None
# 19  432682        Jim         Madge         jmadge@turing.ac.uk  None
# 20  450110      Amber          Raza          araza@turing.ac.uk  None
# 21  452139      Kasra      Hosseini      khosseini@turing.ac.uk  None
# 22  458587      Oscar         Giles         ogiles@turing.ac.uk  None
# 23  458588       Joel       Dearden       jdearden@turing.ac.uk  None
# 24  458589     Amaani       Hoddoon       ahoddoon@turing.ac.uk  None
# 25  460554       Jack       Roberts       jroberts@turing.ac.uk  None
# 26  472253     Oliver       Forrest       oforrest@turing.ac.uk  None
# 27  474864    Gabriel       Hanganu       ghanganu@turing.ac.uk  None
#
#     harvest_user_id     login  subscribed  admin  archived  weekly_capacity  \
# 0         2315537.0   enabled        True   True     False              NaN
# 1               NaN  disabled       False  False     False              NaN
# 2         2360118.0   enabled       False   True     False              NaN
# 3         2360119.0   enabled       False   True     False              NaN
# 4         2360121.0   enabled       False   True     False              NaN
# 5         2360123.0   enabled       False   True     False              NaN
# 6         2360125.0   enabled        True   True     False              NaN
# 7         2360126.0   enabled       False   True     False              NaN
# 8         2360127.0   enabled       False   True     False              NaN
# 9         2360128.0   enabled        True   True     False              NaN
# 10        2360129.0   enabled       False   True     False              NaN
# 11        2360130.0   enabled       False   True     False              NaN
# 12        2360132.0   enabled        True   True     False              NaN
# 13        2360135.0   enabled       False   True     False              NaN
# 14        2392818.0   enabled       False   True     False              NaN
# 15        2412156.0   enabled       False   True     False              NaN
# 16        2421791.0   enabled       False   True     False              NaN
# 17        2443850.0   enabled       False   True     False              NaN
# 18        2456649.0   enabled        True   True     False              NaN
# 19        2463055.0   enabled       False   True     False              NaN
# 20        2549582.0   enabled       False   True     False              0.0
# 21        2559739.0   enabled        True   True     False              NaN
# 22        2593869.0   enabled        True   True     False              NaN
# 23        2563774.0  disabled       False  False     False              NaN
# 24        2593895.0   enabled        True   True     False              NaN
# 25        2603234.0   enabled        True   True     False              NaN
# 26        2747278.0   invited       False   True     False              NaN
# 27        2764181.0   enabled        True   True     False              0.0
#
#     working_days_monday  working_days_tuesday  working_days_wednesday  \
# 0                  True                  True                    True
# 1                  True                  True                    True
# 2                  True                  True                    True
# 3                  True                  True                    True
# 4                  True                  True                    True
# 5                  True                  True                    True
# 6                  True                  True                    True
# 7                  True                  True                    True
# 8                  True                  True                    True
# 9                  True                  True                    True
# 10                 True                  True                    True
# 11                 True                  True                    True
# 12                 True                  True                    True
# 13                 True                  True                    True
# 14                 True                  True                    True
# 15                 True                  True                    True
# 16                 True                  True                    True
# 17                 True                  True                    True
# 18                 True                  True                    True
# 19                 True                  True                    True
# 20                 True                  True                    True
# 21                 True                  True                    True
# 22                 True                  True                    True
# 23                 True                  True                    True
# 24                 True                  True                    True
# 25                 True                  True                    True
# 26                 True                  True                    True
# 27                 True                  True                    True
#
#     working_days_thursday  working_days_friday  working_days_saturday  \
# 0                    True                 True                  False
# 1                    True                 True                  False
# 2                    True                 True                  False
# 3                    True                 True                  False
# 4                    True                 True                  False
# 5                    True                 True                  False
# 6                    True                 True                  False
# 7                    True                 True                  False
# 8                    True                 True                  False
# 9                    True                 True                  False
# 10                   True                 True                  False
# 11                   True                 True                  False
# 12                   True                 True                  False
# 13                   True                 True                  False
# 14                   True                 True                  False
# 15                   True                 True                  False
# 16                   True                 True                  False
# 17                   True                 True                  False
# 18                   True                 True                  False
# 19                   True                 True                  False
# 20                   True                 True                  False
# 21                   True                 True                  False
# 22                   True                 True                  False
# 23                   True                 True                  False
# 24                   True                 True                  False
# 25                   True                 True                  False
# 26                   True                 True                  False
# 27                   True                 True                  False
#
#     working_days_sunday
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
# 5                 False
# 6                 False
# 7                 False
# 8                 False
# 9                 False
# 10                False
# 11                False
# 12                False
# 13                False
# 14                False
# 15                False
# 16                False
# 17                False
# 18                False
# 19                False
# 20                False
# 21                False
# 22                False
# 23                False
# 24                False
# 25                False
# 26                False
# 27                False

# %%
with open('config.json', 'r') as f:
    config = json.load(f)

with open(os.path.expanduser("~/.pgpass"), 'r') as f:
    secrets = None
    for line in f:
        if config['host'] in line:
            secrets = line.strip().split(':')
            break
    
if secrets is None:
    raise ValueError('did not find '+config['host']+' in ~/.pgpass')

url = db.engine.url.URL(drivername=config['drivername'], 
                        username=secrets[-2], 
                        password=secrets[-1],
                        host=config['host'], 
                        database=config['database'])

engine = db.create_engine(url)

connection = engine.connect()

table_name = 'people'

df = pd.read_sql_table(table_name, connection, schema='forecast', index_col='id')
df
# Out:
#        first_name     last_name                       email  role  \
# id
# 399979     Oliver     Strickson     ostrickson@turing.ac.uk  None
# 408178      Angus      Williams      awilliams@turing.ac.uk  None
# 408179      David        Beavan        dbeavan@turing.ac.uk  None
# 408180    Evelina      Gabasova      egabasova@turing.ac.uk  None
# 408181   Giovanni     Colavizza     gcolavizza@turing.ac.uk  None
# 408182      James        Geddes        jgeddes@turing.ac.uk  None
# 408183      James  Hetherington  jhetherington@turing.ac.uk  None
# 408184     Louise        Bowler        lbowler@turing.ac.uk  None
# 408185     Martin      O'Reilly       moreilly@turing.ac.uk  None
# 408186        May          Yong          myong@turing.ac.uk  None
# 408187       Nick        Barlow        nbarlow@turing.ac.uk  None
# 408188      Radka     Jersakova     rjersakova@turing.ac.uk  None
# 408189    Timothy        Hobson        thobson@turing.ac.uk  None
# 408190      Tomas     Lazauskas     tlazauskas@turing.ac.uk  None
# 417332     Camila  Rangel Smith   crangelsmith@turing.ac.uk  None
# 428845      Sarah        Gibson        sgibson@turing.ac.uk  None
# 428846      James      Robinson      jrobinson@turing.ac.uk  None
# 428847     Miguel         Morin         mmorin@turing.ac.uk  None
# 432681       Eric          Daub          edaub@turing.ac.uk  None
# 432682        Jim         Madge         jmadge@turing.ac.uk  None
# 450110      Amber          Raza          araza@turing.ac.uk  None
# 452139      Kasra      Hosseini      khosseini@turing.ac.uk  None
# 458587      Oscar         Giles         ogiles@turing.ac.uk  None
# 458588       Joel       Dearden       jdearden@turing.ac.uk  None
# 458589     Amaani       Hoddoon       ahoddoon@turing.ac.uk  None
# 460554       Jack       Roberts       jroberts@turing.ac.uk  None
# 472253     Oliver       Forrest       oforrest@turing.ac.uk  None
# 474864    Gabriel       Hanganu       ghanganu@turing.ac.uk  None
#
#         harvest_user_id     login  subscribed  admin  archived  \
# id
# 399979        2315537.0   enabled        True   True     False
# 408178              NaN  disabled       False  False     False
# 408179        2360118.0   enabled       False   True     False
# 408180        2360119.0   enabled       False   True     False
# 408181        2360121.0   enabled       False   True     False
# 408182        2360123.0   enabled       False   True     False
# 408183        2360125.0   enabled        True   True     False
# 408184        2360126.0   enabled       False   True     False
# 408185        2360127.0   enabled       False   True     False
# 408186        2360128.0   enabled        True   True     False
# 408187        2360129.0   enabled       False   True     False
# 408188        2360130.0   enabled       False   True     False
# 408189        2360132.0   enabled        True   True     False
# 408190        2360135.0   enabled       False   True     False
# 417332        2392818.0   enabled       False   True     False
# 428845        2412156.0   enabled       False   True     False
# 428846        2421791.0   enabled       False   True     False
# 428847        2443850.0   enabled       False   True     False
# 432681        2456649.0   enabled        True   True     False
# 432682        2463055.0   enabled       False   True     False
# 450110        2549582.0   enabled       False   True     False
# 452139        2559739.0   enabled        True   True     False
# 458587        2593869.0   enabled        True   True     False
# 458588        2563774.0  disabled       False  False     False
# 458589        2593895.0   enabled        True   True     False
# 460554        2603234.0   enabled        True   True     False
# 472253        2747278.0   invited       False   True     False
# 474864        2764181.0   enabled        True   True     False
#
#         weekly_capacity  working_days_monday  working_days_tuesday  \
# id
# 399979              NaN                 True                  True
# 408178              NaN                 True                  True
# 408179              NaN                 True                  True
# 408180              NaN                 True                  True
# 408181              NaN                 True                  True
# 408182              NaN                 True                  True
# 408183              NaN                 True                  True
# 408184              NaN                 True                  True
# 408185              NaN                 True                  True
# 408186              NaN                 True                  True
# 408187              NaN                 True                  True
# 408188              NaN                 True                  True
# 408189              NaN                 True                  True
# 408190              NaN                 True                  True
# 417332              NaN                 True                  True
# 428845              NaN                 True                  True
# 428846              NaN                 True                  True
# 428847              NaN                 True                  True
# 432681              NaN                 True                  True
# 432682              NaN                 True                  True
# 450110              0.0                 True                  True
# 452139              NaN                 True                  True
# 458587              NaN                 True                  True
# 458588              NaN                 True                  True
# 458589              NaN                 True                  True
# 460554              NaN                 True                  True
# 472253              NaN                 True                  True
# 474864              0.0                 True                  True
#
#         working_days_wednesday  working_days_thursday  working_days_friday  \
# id
# 399979                    True                   True                 True
# 408178                    True                   True                 True
# 408179                    True                   True                 True
# 408180                    True                   True                 True
# 408181                    True                   True                 True
# 408182                    True                   True                 True
# 408183                    True                   True                 True
# 408184                    True                   True                 True
# 408185                    True                   True                 True
# 408186                    True                   True                 True
# 408187                    True                   True                 True
# 408188                    True                   True                 True
# 408189                    True                   True                 True
# 408190                    True                   True                 True
# 417332                    True                   True                 True
# 428845                    True                   True                 True
# 428846                    True                   True                 True
# 428847                    True                   True                 True
# 432681                    True                   True                 True
# 432682                    True                   True                 True
# 450110                    True                   True                 True
# 452139                    True                   True                 True
# 458587                    True                   True                 True
# 458588                    True                   True                 True
# 458589                    True                   True                 True
# 460554                    True                   True                 True
# 472253                    True                   True                 True
# 474864                    True                   True                 True
#
#         working_days_saturday  working_days_sunday
# id
# 399979                  False                False
# 408178                  False                False
# 408179                  False                False
# 408180                  False                False
# 408181                  False                False
# 408182                  False                False
# 408183                  False                False
# 408184                  False                False
# 408185                  False                False
# 408186                  False                False
# 408187                  False                False
# 408188                  False                False
# 408189                  False                False
# 408190                  False                False
# 417332                  False                False
# 428845                  False                False
# 428846                  False                False
# 428847                  False                False
# 432681                  False                False
# 432682                  False                False
# 450110                  False                False
# 452139                  False                False
# 458587                  False                False
# 458588                  False                False
# 458589                  False                False
# 460554                  False                False
# 472253                  False                False
# 474864                  False                False

# %%
idx = connection.execute('SELECT id FROM forecast.people').fetchall()
idx = list(zip(*result))[0]
# Out:
# (399979,
#  408178,
#  408179,
#  408180,
#  408181,
#  408182,
#  408183,
#  408184,
#  408185,
#  408186,
#  408187,
#  408188,
#  408189,
#  408190,
#  417332,
#  428845,
#  428846,
#  428847,
#  432681,
#  432682,
#  450110,
#  452139,
#  458587,
#  458588,
#  458589,
#  460554,
#  472253,
#  474864)

# %%
408180 in list(zip(*result))[0]

df.loc[[row for row in df.index if row not in idx], :]
# Out:
# Empty DataFrame
# Columns: [first_name, last_name, email, role, harvest_user_id, login, subscribed, admin, archived, weekly_capacity, working_days_monday, working_days_tuesday, working_days_wednesday, working_days_thursday, working_days_friday, working_days_saturday, working_days_sunday]
# Index: []
